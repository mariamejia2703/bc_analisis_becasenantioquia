# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamejia2703/bc_analisis_becasenantioquia/blob/master/TrabajoFinalBootcampAnalisisDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hecho por:
#
#
# *   Maria Isabel Bohorquez Mejia
# *   Carolina Rios Benavides

# %% [markdown]
# # **Beneficiaros de becas y créditos de programas de acceso a la educación superior de Antioquia**

# %% [markdown]
# Base de datos con información anonimizada de las personas que han sido beneficiarias de los programas de subsidios, becas condicionadas y créditos condonables que administra la Corporación Gilberto Echeverri Mejía, destinadas para la población del Departamento de Antioquia que reside fuera de la ciudad de Medellín.

# %% [markdown]
# # Presentación

# %% [markdown]
# El presente análisis se basa en el conjunto de datos públicos proporcionado por el portal de **datos abiertos del Gobierno de Colombia** , específicamente el titulado **“Beneficiaros de becas y creditos de programas de acceso a la educación superior de Antioquia”** (fuente: https://www.datos.gov.co/Educaci-n/Beneficiaros-de-becas-y-creditos-de-programas-de-a/ya7f-466y/about_data). Este dataset recoge información relevante sobre los beneficiarios que han accedido a becas y creditos para la educación superior a través de la **CORPORACION GILBERTO ECHEVERRI MEJIA.**
#
# El dataset contiene información actualizada hasta el 20 de mayo de 2024, con un total aproximado de 14.600 registros distribuidos en 17 columnas, que describen variables relevantes como el beneficio otorgado, género del beneficiario, ubicación geográfica (departamento y municipio), y el estado del beneficio, entre otros.
#
# No obstante, se identificó una limitación significativa: no se incluye el valor monetario de los beneficios otorgados, lo cual restringe la posibilidad de realizar análisis financieros o presupuestarios detallados, como la distribución de recursos por región, año o tipo de programa.
#
# A pesar de esta carencia, el conjunto de datos sigue siendo altamente útil para realizar otros tipos de análisis.
#
# Por lo tanto, aunque el análisis financiero se ve limitado, el dataset conserva un alto valor para estudios de acceso, equidad y focalización en la educación superior.

# %% [markdown]
# # Justificación

# %% [markdown]
# El dataset titulado ““Beneficiaros de becas y creditos de programas de acceso a la educación superior de Antioquia”, disponible en el portal oficial de datos abiertos de Colombia (datos.gov.co), ha sido seleccionado para este análisis debido a sus características técnicas que lo hacen adecuado para un estudio estadístico, geográfico y temporal confiable. A continuación se detallan las razones técnicas principales:
#
# 1. Formato estructurado y reutilizable
# 2. Estructura tabular clara (variables categóricas, numéricas y temporales bien definidas)
# 3. Cobertura histórica y temporal
# 4. Georreferenciación implícita
# 5. Calidad y origen de los datos
# 6. Aplicabilidad analítica

# %% [markdown]
# # Ingestión de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('/content/Beneficiaros_de_becas_y_creditos_de_programas_de_acceso_a_la_educaci_n_superior_de_Antioquia_20250721.csv')
df
# Out:
#        CONVOCATORIA  SEMESTRE DE CONVOCATORIA         BENEFICIO OTORGADO  \
# 0              2016                         1  MATRICULA Y SOSTENIMIENTO
# 1              2016                         1  MATRICULA Y SOSTENIMIENTO
# 2              2016                         1  MATRICULA Y SOSTENIMIENTO
# 3              2016                         1  MATRICULA Y SOSTENIMIENTO
# 4              2016                         1  MATRICULA Y SOSTENIMIENTO
# ...             ...                       ...                        ...
# 14561          2024                         1              SOSTENIMIENTO
# 14562          2024                         1              SOSTENIMIENTO
# 14563          2024                         1              SOSTENIMIENTO
# 14564          2024                         1              SOSTENIMIENTO
# 14565          2024                         1              SOSTENIMIENTO
#
#       DEPARTAMENTO DE NACIMIENTO MUNICIPIO DE NACIMIENTO  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CONVOCATORIA                  14566 non-null  int64
#  1   SEMESTRE DE CONVOCATORIA      14566 non-null  int64
#  2   BENEFICIO OTORGADO            14566 non-null  object
#  3   DEPARTAMENTO DE NACIMIENTO    14566 non-null  object
#  4   MUNICIPIO DE NACIMIENTO       14566 non-null  object
#  5   FECHA DE NACIMIENTO           14566 non-null  object
#  6   GÉNERO                        14566 non-null  object
#  7   SUBREGIÓN DE RESIDENCIA       14566 non-null  object
#  8   MUNICIPIO DE RESIDENCIA       14566 non-null  object
#  9   ESTRATO                       14566 non-null  object
#  10  GRUPO ETNICO                  14566 non-null  object
#  11  VICTIMA DEL CONFLICTO ARMADO  14566 non-null  object
# ...

# %%
df.describe()
# Out:
#        CONVOCATORIA  SEMESTRE DE CONVOCATORIA
# count  14566.000000              14566.000000
# mean    2015.828230                  1.552176
# std        2.752501                  0.497287
# min     2013.000000                  1.000000
# 25%     2014.000000                  1.000000
# 50%     2015.000000                  2.000000
# 75%     2017.000000                  2.000000
# max     2024.000000                  2.000000

# %% [markdown]
# # Preparación y limpieza

# %%
#ver la información de las columnas y los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CONVOCATORIA                  14566 non-null  int64
#  1   SEMESTRE DE CONVOCATORIA      14566 non-null  int64
#  2   BENEFICIO OTORGADO            14566 non-null  object
#  3   DEPARTAMENTO DE NACIMIENTO    14566 non-null  object
#  4   MUNICIPIO DE NACIMIENTO       14566 non-null  object
#  5   FECHA DE NACIMIENTO           14566 non-null  object
#  6   GÉNERO                        14566 non-null  object
#  7   SUBREGIÓN DE RESIDENCIA       14566 non-null  object
#  8   MUNICIPIO DE RESIDENCIA       14566 non-null  object
#  9   ESTRATO                       14566 non-null  object
#  10  GRUPO ETNICO                  14566 non-null  object
#  11  VICTIMA DEL CONFLICTO ARMADO  14566 non-null  object
# ...

# %%
#Ver los nombres de las columnas
df.columns
# Out:
# Index(['CONVOCATORIA', 'SEMESTRE DE CONVOCATORIA', 'BENEFICIO OTORGADO',
#        'DEPARTAMENTO DE NACIMIENTO', 'MUNICIPIO DE NACIMIENTO',
#        'FECHA DE NACIMIENTO', 'GÉNERO', 'SUBREGIÓN DE RESIDENCIA',
#        'MUNICIPIO DE RESIDENCIA', 'ESTRATO', 'GRUPO ETNICO',
#        'VICTIMA DEL CONFLICTO ARMADO', 'UNIVERSIDAD', 'PROGRAMA CURSADO',
#        'MUNICIPIO OFERTA', 'TIPO DE FORMACIÓN', 'GRADUADO'],
#       dtype='object')

# %%
#convertir las columnas en minusculas y reemplazar los espacios por guiones bajos para evitar errores de sintaxis
df.columns = df.columns.str.lower().str.replace(" ","_")
df.columns
# Out:
# Index(['convocatoria', 'semestre_de_convocatoria', 'beneficio_otorgado',
#        'departamento_de_nacimiento', 'municipio_de_nacimiento',
#        'fecha_de_nacimiento', 'género', 'subregión_de_residencia',
#        'municipio_de_residencia', 'estrato', 'grupo_etnico',
#        'victima_del_conflicto_armado', 'universidad', 'programa_cursado',
#        'municipio_oferta', 'tipo_de_formación', 'graduado'],
#       dtype='object')

# %%
#Crear columna nueva en el dataframe que nos pueda traer la columna 'FECHA DE NACIMIENTO' en tipo de dato FECHA
df['fecha']=pd.to_datetime(df['fecha_de_nacimiento'])
df
# Out:
# /tmp/ipython-input-9-3167315547.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['fecha']=pd.to_datetime(df['fecha_de_nacimiento'])
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 0              2016                         1  MATRICULA Y SOSTENIMIENTO
# 1              2016                         1  MATRICULA Y SOSTENIMIENTO
# 2              2016                         1  MATRICULA Y SOSTENIMIENTO
# 3              2016                         1  MATRICULA Y SOSTENIMIENTO
# 4              2016                         1  MATRICULA Y SOSTENIMIENTO
# ...             ...                       ...                        ...
# 14561          2024                         1              SOSTENIMIENTO
# 14562          2024                         1              SOSTENIMIENTO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   convocatoria                  14566 non-null  int64
#  1   semestre_de_convocatoria      14566 non-null  int64
#  2   beneficio_otorgado            14566 non-null  object
#  3   departamento_de_nacimiento    14566 non-null  object
#  4   municipio_de_nacimiento       14566 non-null  object
#  5   fecha_de_nacimiento           14566 non-null  object
#  6   género                        14566 non-null  object
#  7   subregión_de_residencia       14566 non-null  object
#  8   municipio_de_residencia       14566 non-null  object
#  9   estrato                       14566 non-null  object
#  10  grupo_etnico                  14566 non-null  object
#  11  victima_del_conflicto_armado  14566 non-null  object
# ...

# %%
#Crear la columna 'año_nacimiento' desde la columna de fecha, y así extraer el año de nacimiento de cada persona.
df['anio_nacimiento']=df['fecha'].dt.year
df
# Out:
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 0              2016                         1  MATRICULA Y SOSTENIMIENTO
# 1              2016                         1  MATRICULA Y SOSTENIMIENTO
# 2              2016                         1  MATRICULA Y SOSTENIMIENTO
# 3              2016                         1  MATRICULA Y SOSTENIMIENTO
# 4              2016                         1  MATRICULA Y SOSTENIMIENTO
# ...             ...                       ...                        ...
# 14561          2024                         1              SOSTENIMIENTO
# 14562          2024                         1              SOSTENIMIENTO
# 14563          2024                         1              SOSTENIMIENTO
# 14564          2024                         1              SOSTENIMIENTO
# 14565          2024                         1              SOSTENIMIENTO
#
#       departamento_de_nacimiento municipio_de_nacimiento  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   convocatoria                  14566 non-null  int64
#  1   semestre_de_convocatoria      14566 non-null  int64
#  2   beneficio_otorgado            14566 non-null  object
#  3   departamento_de_nacimiento    14566 non-null  object
#  4   municipio_de_nacimiento       14566 non-null  object
#  5   fecha_de_nacimiento           14566 non-null  object
#  6   género                        14566 non-null  object
#  7   subregión_de_residencia       14566 non-null  object
#  8   municipio_de_residencia       14566 non-null  object
#  9   estrato                       14566 non-null  object
#  10  grupo_etnico                  14566 non-null  object
#  11  victima_del_conflicto_armado  14566 non-null  object
# ...

# %%
#Crear columna 'edad', esto a partir de la resta de 'convocatoria' - 'anio_nacimiento', y así poder obtener la edad del candidato al momento de obtener la beca
df['edad']=df['convocatoria']-df['anio_nacimiento']
df
# Out:
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 0              2016                         1  MATRICULA Y SOSTENIMIENTO
# 1              2016                         1  MATRICULA Y SOSTENIMIENTO
# 2              2016                         1  MATRICULA Y SOSTENIMIENTO
# 3              2016                         1  MATRICULA Y SOSTENIMIENTO
# 4              2016                         1  MATRICULA Y SOSTENIMIENTO
# ...             ...                       ...                        ...
# 14561          2024                         1              SOSTENIMIENTO
# 14562          2024                         1              SOSTENIMIENTO
# 14563          2024                         1              SOSTENIMIENTO
# 14564          2024                         1              SOSTENIMIENTO
# 14565          2024                         1              SOSTENIMIENTO
#
#       departamento_de_nacimiento municipio_de_nacimiento  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   convocatoria                  14566 non-null  int64
#  1   semestre_de_convocatoria      14566 non-null  int64
#  2   beneficio_otorgado            14566 non-null  object
#  3   departamento_de_nacimiento    14566 non-null  object
#  4   municipio_de_nacimiento       14566 non-null  object
#  5   fecha_de_nacimiento           14566 non-null  object
#  6   género                        14566 non-null  object
#  7   subregión_de_residencia       14566 non-null  object
#  8   municipio_de_residencia       14566 non-null  object
#  9   estrato                       14566 non-null  object
#  10  grupo_etnico                  14566 non-null  object
#  11  victima_del_conflicto_armado  14566 non-null  object
# ...

# %%
df[df['edad']==13]
# Out:
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 13766          2021                         2  MATRICULA Y SOSTENIMIENTO
#
#       departamento_de_nacimiento municipio_de_nacimiento  \
# 13766                  ANTIOQUIA                ZARAGOZA
#
#           fecha_de_nacimiento    género subregión_de_residencia  \
# 13766  06/26/2008 12:00:00 AM  FEMENINO                NORDESTE
#
#       municipio_de_residencia    estrato grupo_etnico  \
# 13766                   ANORI  ESTRATO 1     INDIGENA
#
#       victima_del_conflicto_armado  \
# 13766                           NO
#
#                                              universidad  \
# 13766  INSTITUCION UNIVERSITARIA POLITECNICO GRANCOLO...
#
#                       programa_cursado municipio_oferta tipo_de_formación  \
# 13766  TECNOLOGIA EN GESTION AMBIENTAL         MEDELLIN       TECNOLOGICA
#
#       graduado      fecha  anio_nacimiento  edad
# 13766       NO 2008-06-26             2008    13

# %%
df[df['edad']==62]
# Out:
#      convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 643          2014                         2  MATRICULA Y SOSTENIMIENTO
#
#     departamento_de_nacimiento municipio_de_nacimiento  \
# 643                  ANTIOQUIA                ABRIAQUI
#
#         fecha_de_nacimiento     género subregión_de_residencia  \
# 643  11/14/1952 12:00:00 AM  MASCULINO               OCCIDENTE
#
#     municipio_de_residencia    estrato grupo_etnico  \
# 643                ABRIAQUI  ESTRATO 2      NINGUNO
#
#     victima_del_conflicto_armado                              universidad  \
# 643                           NO  INSTITUCION UNIVERSITARIA PASCUAL BRAVO
#
#                       programa_cursado municipio_oferta tipo_de_formación  \
# 643  TECNOLOGIA EN MECANICA AUTOMOTRIZ      CAÑASGORDAS       TECNOLOGICA
#
#     graduado      fecha  anio_nacimiento  edad
# 643       SI 1952-11-14             1952    62

# %%
#eliminar las columnas 'fecha_de_nacimiento' y 'fecha', ya que ya no son de utilidad
df.drop(['fecha_de_nacimiento','fecha'],axis=1, inplace=True)
df
# Out:
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 0              2016                         1  MATRICULA Y SOSTENIMIENTO
# 1              2016                         1  MATRICULA Y SOSTENIMIENTO
# 2              2016                         1  MATRICULA Y SOSTENIMIENTO
# 3              2016                         1  MATRICULA Y SOSTENIMIENTO
# 4              2016                         1  MATRICULA Y SOSTENIMIENTO
# ...             ...                       ...                        ...
# 14561          2024                         1              SOSTENIMIENTO
# 14562          2024                         1              SOSTENIMIENTO
# 14563          2024                         1              SOSTENIMIENTO
# 14564          2024                         1              SOSTENIMIENTO
# 14565          2024                         1              SOSTENIMIENTO
#
#       departamento_de_nacimiento municipio_de_nacimiento     género  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   convocatoria                  14566 non-null  int64
#  1   semestre_de_convocatoria      14566 non-null  int64
#  2   beneficio_otorgado            14566 non-null  object
#  3   departamento_de_nacimiento    14566 non-null  object
#  4   municipio_de_nacimiento       14566 non-null  object
#  5   género                        14566 non-null  object
#  6   subregión_de_residencia       14566 non-null  object
#  7   municipio_de_residencia       14566 non-null  object
#  8   estrato                       14566 non-null  object
#  9   grupo_etnico                  14566 non-null  object
#  10  victima_del_conflicto_armado  14566 non-null  object
#  11  universidad                   14566 non-null  object
# ...

# %%
df.describe()
# Out:
#        convocatoria  semestre_de_convocatoria  anio_nacimiento          edad
# count  14566.000000              14566.000000     14566.000000  14566.000000
# mean    2015.828230                  1.552176      1994.851023     20.977207
# std        2.752501                  0.497287         4.942420      4.366386
# min     2013.000000                  1.000000      1952.000000     13.000000
# 25%     2014.000000                  1.000000      1993.000000     18.000000
# 50%     2015.000000                  2.000000      1995.000000     20.000000
# 75%     2017.000000                  2.000000      1998.000000     22.000000
# max     2024.000000                  2.000000      2009.000000     62.000000

# %% [markdown]
# # Analítica descriptiva

# %%
df['género'].value_counts()
# Out:
# género
# FEMENINO     7888
# MASCULINO    6678
# Name: count, dtype: int64

# %%
df['grupo_etnico'].value_counts()
# Out:
# grupo_etnico
# NINGUNO           13930
# AFROCOLOMBIANO      520
# INDIGENA            116
# Name: count, dtype: int64

# %%
df['victima_del_conflicto_armado'].value_counts()
# Out:
# victima_del_conflicto_armado
# NO    10591
# SI     3975
# Name: count, dtype: int64

# %%
df['estrato'].value_counts()
# Out:
# estrato
# ESTRATO 2    6939
# ESTRATO 1    4936
# ESTRATO 3    2657
# Estrato 2      16
# Estrato 3       8
# ESTRATO 4       7
# ESTRATO 5       2
# Estrato 1       1
# Name: count, dtype: int64

# %%
df['tipo_de_formación'].value_counts()
# Out:
# tipo_de_formación
# UNIVERSITARIA          8365
# TECNOLOGICA            5235
# TECNICA PROFESIONAL     489
# NORMALISTA              454
# POSTGRADO                20
# Universitaria             3
# Name: count, dtype: int64

# %%
#Convertir todo en minuscula
df['tipo_de_formación'] = df['tipo_de_formación'].str.lower()
df['tipo_de_formación'].value_counts()
# Out:
# tipo_de_formación
# universitaria          8368
# tecnologica            5235
# tecnica profesional     489
# normalista              454
# postgrado                20
# Name: count, dtype: int64

# %%
df['beneficio_otorgado'].value_counts()
# Out:
# beneficio_otorgado
# MATRICULA Y SOSTENIMIENTO    11431
# MATRICULA                     1579
# SOSTENIMIENTO                 1556
# Name: count, dtype: int64

# %%
df['edad'].mode()
# Out:
# 0    18
# Name: edad, dtype: int64

# %%
df['edad'].mean()
# Out:
# np.float64(20.97720719483729)

# %%
df['programa_cursado'].value_counts().head(20)
# Out:
# programa_cursado
# ADMINISTRACION DE EMPRESAS                709
# CONTADURIA PUBLICA                        598
# LIC. EN EDUCACION PREESCOLAR              596
# TECNOLOGIA AGROAMBIENTAL                  520
# CICLO COMPLEMENTARIO                      454
# PSICOLOGIA                                421
# INGENIERIA AMBIENTAL                      366
# TECNOLOGIA EN GESTION PÚBLICA             350
# TECNOLOGIA EN PRODUCCION AGROECOLOGICA    333
# TECNOLOGIA EN ENTRENAMIENTO DEPORTIVO     316
# TECNOLOGIA EN PRODUCCION AGROPECUARIA     298
# INGENIERIA AGROPECUARIA                   261
# TECNOLOGIA EN SISTEMAS MECATRONICOS       256
# INGENIERIA DE SISTEMAS                    234
# INGENIERIA INDUSTRIAL                     228
# TRABAJO SOCIAL                            227
# TECNOLOGIA EN CONSTRUCCIONES CIVILES      206
# LIC. EN LENGUAS EXTRANJERAS               204
# INGENIERIA CIVIL                          199
# TECNOLOGIA EN MECANICA AUTOMOTRIZ         192
# ...

# %%
df['programa_cursado'].mode()
# Out:
# 0    ADMINISTRACION DE EMPRESAS
# Name: programa_cursado, dtype: object

# %% [markdown]
# ##Valores atípicos

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df[['edad']])
plt.title("Boxplot");

# %%
def detectar_outliers(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < Q1 - 1.5 * IQR) | (df[col] > Q3 + 1.5 * IQR)]
    return outliers

# %%
#traemos los registros outliers por edad
outliers_edad = detectar_outliers("edad")
print("Outliers edad: ")
print(outliers_edad)
# Out:
# Outliers edad:
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 130            2014                         1                  MATRICULA
# 137            2014                         1  MATRICULA Y SOSTENIMIENTO
# 160            2014                         1  MATRICULA Y SOSTENIMIENTO
# 176            2015                         2  MATRICULA Y SOSTENIMIENTO
# 185            2015                         2  MATRICULA Y SOSTENIMIENTO
# ...             ...                       ...                        ...
# 14542          2024                         1              SOSTENIMIENTO
# 14547          2024                         1              SOSTENIMIENTO
# 14550          2024                         1              SOSTENIMIENTO
# 14557          2024                         1              SOSTENIMIENTO
# 14565          2024                         1              SOSTENIMIENTO
#
#       departamento_de_nacimiento municipio_de_nacimiento     género  \
# ...

# %%
#outliers de convocatoria x edad segmentado por beneficio otorgado
g = sns.catplot(data=df, x='convocatoria', kind='box', y='edad', hue='beneficio_otorgado', height=8, aspect=1.5, legend_out=False)

g.set_titles("Convocatoria: {col_name}")
g.set_axis_labels("Convocatoria", "Edad")


plt.legend(loc='upper left', bbox_to_anchor=(0, 1))


plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
#se define df entre las variables numericas
data = df[['edad','convocatoria']]
data
# Out:
#        edad  convocatoria
# 0        19          2016
# 1        18          2016
# 2        17          2016
# 3        22          2016
# 4        17          2016
# ...     ...           ...
# 14561    17          2024
# 14562    20          2024
# 14563    22          2024
# 14564    27          2024
# 14565    38          2024
#
# [14566 rows x 2 columns]

# %%
#Se crea df resultante de la data sin outliers de edad
Q1 = data['edad'].quantile(0.25)
Q3 = data['edad'].quantile(0.75)

IQR = Q3-Q1

piso=Q1-1.5*IQR
TECHO=Q3+1.5*IQR

data_sin_outliers = data[(data['edad']>=piso) & (data['edad']<=TECHO)]
data_sin_outliers
# Out:
#        edad  convocatoria
# 0        19          2016
# 1        18          2016
# 2        17          2016
# 3        22          2016
# 4        17          2016
# ...     ...           ...
# 14560    19          2024
# 14561    17          2024
# 14562    20          2024
# 14563    22          2024
# 14564    27          2024
#
# [13690 rows x 2 columns]

# %%
#estándariza los datos
scalador = StandardScaler()
data_escalada = scalador.fit_transform(data_sin_outliers)
data_escalada
# Out:
# array([[-0.42144215,  0.08928707],
#        [-0.78089284,  0.08928707],
#        [-1.14034352,  0.08928707],
#        ...,
#        [-0.06199146,  3.03823746],
#        [ 0.65690992,  3.03823746],
#        [ 2.45416336,  3.03823746]])

# %%
#WCSS calcula la distancia entre grupos
WCSS = []
for i in range(1,15):
    km = KMeans(n_clusters=i)
    km.fit(data_escalada)
    WCSS.append(km.inertia_)

# %%
WCSS
# Out:
# [27380.000000000233,
#  16528.219612548826,
#  9087.614025859008,
#  6936.872770904258,
#  5202.789969078068,
#  4698.567983854978,
#  3804.5806350520725,
#  3436.6765256673275,
#  2900.2929703982095,
#  2721.8341820569335,
#  2571.642292473032,
#  2341.5387054105477,
#  2086.8407560718683,
#  1975.6993037732102]

# %%
#aplicamos la figura (método del codo)
plt.figure(figsize=(10,5))
plt.plot(range(1,15),WCSS)
plt.show()

# %%
km = KMeans(n_clusters=3)
km.fit(data_escalada)
# Out:
# KMeans(n_clusters=3)

# %%
km.fit_predict(data_escalada)
# Out:
# array([1, 1, 1, ..., 2, 2, 2], dtype=int32)

# %%
from sklearn.metrics import silhouette_score

# %%
#Se ejecuta el método de silueta,El análisis de silueta se puede utilizar para examinar la cantidad de separación entre los grupos.
silueta=[]
for i in range(2,15):
    km = KMeans(n_clusters=i)
    clusters = km.fit_predict(data_escalada)
    silueta_prom=silhouette_score(data_escalada,clusters)
    silueta.append(silueta_prom)

silueta
# Out:
# [np.float64(0.4205222687568339),
#  np.float64(0.5056565305633365),
#  np.float64(0.49586735229177836),
#  np.float64(0.43789866273089517),
#  np.float64(0.42907689880716926),
#  np.float64(0.42816158615289235),
#  np.float64(0.36287918656334006),
#  np.float64(0.38206546773385175),
#  np.float64(0.37810083402543426),
#  np.float64(0.37879194478782546),
#  np.float64(0.3940501643964563),
#  np.float64(0.38612619114250923),
#  np.float64(0.4049900342963952)]

# %%
plt.figure(figsize=(10,5))
plt.plot(range(2,15),silueta, marker='o')
plt.title("Coeficiente de silueta para diverson valores de K")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Coeficiente de silueta")
plt.show()

# %%
k_optimo = 3
modelo_km = KMeans(n_clusters=k_optimo)
clusters = modelo_km.fit_predict(data_escalada)

# %%
#se crea la columna cluster y se asigna la variable cluster
data_sin_outliers['cluster']=clusters
data_sin_outliers
# Out:
# /tmp/ipython-input-48-782155358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sin_outliers['cluster']=clusters
#        edad  convocatoria  cluster
# 0        19          2016        0
# 1        18          2016        0
# 2        17          2016        0
# 3        22          2016        1
# 4        17          2016        0
# ...     ...           ...      ...
# 14560    19          2024        2
# 14561    17          2024        2
# 14562    20          2024        2
# 14563    22          2024        2
# 14564    27          2024        2
#
# [13690 rows x 3 columns]

# %%
data_sin_outliers['cluster'].unique()
# Out:
# array([0, 1, 2], dtype=int32)

# %%
plt.figure(figsize=(12,8))
for cluster in sorted(data_sin_outliers['cluster'].unique()):
    plt.scatter(
        data_sin_outliers.loc[data_sin_outliers['cluster']==cluster,'edad'],
        data_sin_outliers.loc[data_sin_outliers['cluster']==cluster,'convocatoria'],
        label=f'Cluster {cluster}'
    )

# %%
scalador.inverse_transform(modelo_km.cluster_centers_)
# Out:
# array([[  18.73312102, 2014.46254777],
#        [  24.32081218, 2014.85752961],
#        [  19.83986135, 2020.20415945]])

# %%
plt.figure(figsize=(12, 8))
for cluster in sorted(data_sin_outliers["cluster"].unique()):
  plt.scatter(
      data_sin_outliers.loc[data_sin_outliers["cluster"] == cluster,"edad"],
      data_sin_outliers.loc[data_sin_outliers["cluster"] == cluster,"convocatoria"],
      label=f"Cluster{cluster}"
  )

centroides = scalador.inverse_transform(modelo_km.cluster_centers_)
plt.scatter(centroides[:, 0], centroides [:,1], s=100, c='red', marker='x',label='Centroides')
plt.show()

# %% [markdown]
# # Análisis de negocio

# %% [markdown]
# 1.   ¿Qué municipios de Antioquia presentan mayor número de beneficiarios por año?
#
# 3. ¿Qué tipo de apoyos (becas o créditos) son más frecuentes y en qué zonas? (beneficio otorgado, municipio de residencia)
#
# 4. ¿Cómo ha sido la evolución del acceso a estos beneficios en los últimos años?(conteo de convocatoria por año)
#
# 5. ¿Cuáles son las instituciones más frecuentes a las que acceden los beneficiarios? (universidad, conteo de año nac)
#
# 6. ¿Qué nivel educativo es más apoyado según el municipio?
# (tipo de formacion, municipio residencia - oferta)
#
# 7. ¿Qué porcentaje de beneficiarios corresponde a becas, créditos condonables o mixtos? (beneficio otorgado)
#
# 8. ¿Qué municipios presentan mayor y menor cantidad de beneficiarios?
# (conteo de municipio de residencia)
#
# 9. ¿Qué subregiones de Antioquia están más rezagadas en términos de acceso a apoyos educativos? (subregion con menos apoyo, subregion con beneficio otorgado)
#
# 11. ¿Cuáles son los programas académicos más demandados por genero, edad y subregion? (genero, programa cursado, subregion)
#
# 12. ¿Los estudiantes beneficiarios prefieren formación técnica, tecnológica o profesional? (conteo de tipo de formación)
#
# 13. ¿Cuál es la distribución por género, estrato,grupo-etnico y victima del conflicto armado entre los beneficiarios alrededor de los años? (conteo de genero,año, estrato, conflicto armado)
#
# 14. ¿Qué grupo etario (rango de edad) predomina entre los beneficiarios? (crear columna edad)

# %%
#contar cuantos municipios diferentes de antioquia hay en el dataframe
municipios_diferentes=df['municipio_de_residencia'].nunique()
municipios_diferentes
# Out:
# 125

# %% [markdown]
# 1. ¿Qué municipios de Antioquia presentan mayor número de beneficiarios por año?

# %%
# Agrupar por municipio_de_residencia y convocatoria, y contar beneficiarios
beneficiarios_por_municipio_anio = df.groupby(['convocatoria', 'municipio_de_residencia']).size().sort_values(ascending=False).reset_index(name='num_beneficiarios')
beneficiarios_por_municipio_anio
# Out:
#       convocatoria municipio_de_residencia  num_beneficiarios
# 0             2019                   BELLO                533
# 1             2013                RIONEGRO                329
# 2             2015                RIONEGRO                285
# 3             2014                RIONEGRO                283
# 4             2014                   TURBO                213
# ...            ...                     ...                ...
# 1114          2024    SANTAFE DE ANTIOQUIA                  1
# 1115          2024               SAN PEDRO                  1
# 1116          2024                REMEDIOS                  1
# 1117          2024             PUERTO NARE                  1
# 1118          2024           PUERTO BERRIO                  1
#
# [1119 rows x 3 columns]

# %%
# Para cada año, encontrar el municipio con más beneficiarios
top_municipios_por_año = beneficiarios_por_municipio_anio.sort_values(['convocatoria', 'num_beneficiarios'], ascending=[True, False]).groupby('convocatoria').head(5)

print(top_municipios_por_año)
# Out:
#      convocatoria municipio_de_residencia  num_beneficiarios
# 1            2013                RIONEGRO                329
# 7            2013                APARTADO                184
# 8            2013                 LA CEJA                179
# 9            2013               CHIGORODO                175
# 10           2013                   TURBO                146
# 3            2014                RIONEGRO                283
# 4            2014                   TURBO                213
# 13           2014               CHIGORODO                144
# 14           2014                APARTADO                137
# 15           2014                  SONSON                126
# 2            2015                RIONEGRO                285
# 5            2015                APARTADO                202
# 6            2015               CHIGORODO                193
# 11           2015                 LA CEJA                145
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#grafica, los municipios con mayores beneficiarios por convocatoria
g = sns.FacetGrid(top_municipios_por_año, col="convocatoria", col_wrap=3, height=4, sharex=False)
g.map_dataframe(sns.barplot, x='municipio_de_residencia', y='num_beneficiarios', palette="viridis")

g.set_titles("Convocatoria: {col_name}")
g.set_axis_labels("Municipio", "Beneficiarios")
for ax in g.axes.flat:
    ax.tick_params(labelrotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Respuesta: Se puede verificar que del año 2013 al 2015 Rionegro era uno de los municipios con mayor beneficiarios, y aunque luego de esto bajo su numero se mantuvo hasta el año 2020 entre los 5 primeros municipios con mayor beneficiarios, así como chigorodo, la ceja, etc... pero también se visualiza el hecho de que al pasar de los años el número de beneficiarios baja en gran cantidad, esto es una gran incognita ya que puede ser que antioquia ya no esta otorgando el mismo número de becas o los jovenes no están interesados en estudiar.

# %% [markdown]
# 2. ¿Qué tipo de apoyos (becas o créditos) son más frecuentes y en qué zonas? (beneficio otorgado, municipio de residencia)

# %%
#contar tipos de becas
conteo_de_becas = df.groupby('beneficio_otorgado')['beneficio_otorgado'].count().sort_values(ascending=False).reset_index(name='Total')
conteo_de_becas
# Out:
#           beneficio_otorgado  Total
# 0  MATRICULA Y SOSTENIMIENTO  11431
# 1                  MATRICULA   1579
# 2              SOSTENIMIENTO   1556

# %% [markdown]
# Respuesta: Los tipos de apoyo más frecuentes son matricula y sostenimiento (en conjunto) y matricula, principalmente en Rionegro, Chigorodo, Apartado, Bello y Turbo.

# %%
conteo_de_becas_2=df.groupby(['beneficio_otorgado', 'municipio_de_residencia']).size().sort_values(ascending=False).reset_index(name='num_beneficiarios').head(30)
conteo_de_becas_2
# Out:
#            beneficio_otorgado municipio_de_residencia  num_beneficiarios
# 0   MATRICULA Y SOSTENIMIENTO                RIONEGRO                983
# 1   MATRICULA Y SOSTENIMIENTO               CHIGORODO                629
# 2   MATRICULA Y SOSTENIMIENTO                APARTADO                607
# 3               SOSTENIMIENTO                   BELLO                526
# 4   MATRICULA Y SOSTENIMIENTO                   TURBO                517
# 5   MATRICULA Y SOSTENIMIENTO                 LA CEJA                493
# 6   MATRICULA Y SOSTENIMIENTO    EL CARMEN DE VIBORAL                412
# 7   MATRICULA Y SOSTENIMIENTO                  GUARNE                402
# 8   MATRICULA Y SOSTENIMIENTO                  CAREPA                349
# 9   MATRICULA Y SOSTENIMIENTO               MARINILLA                290
# 10  MATRICULA Y SOSTENIMIENTO                  SONSON                262
# 11  MATRICULA Y SOSTENIMIENTO                   ANDES                254
# ...

# %%
# Ordenar por beneficio otorgado y luego por número de beneficiarios
conteo_de_becas_ordenado = conteo_de_becas_2.sort_values(
    by=['beneficio_otorgado', 'num_beneficiarios'],
    ascending=[False, False]
)
conteo_de_becas_ordenado
# Out:
#            beneficio_otorgado municipio_de_residencia  num_beneficiarios
# 3               SOSTENIMIENTO                   BELLO                526
# 0   MATRICULA Y SOSTENIMIENTO                RIONEGRO                983
# 1   MATRICULA Y SOSTENIMIENTO               CHIGORODO                629
# 2   MATRICULA Y SOSTENIMIENTO                APARTADO                607
# 4   MATRICULA Y SOSTENIMIENTO                   TURBO                517
# 5   MATRICULA Y SOSTENIMIENTO                 LA CEJA                493
# 6   MATRICULA Y SOSTENIMIENTO    EL CARMEN DE VIBORAL                412
# 7   MATRICULA Y SOSTENIMIENTO                  GUARNE                402
# 8   MATRICULA Y SOSTENIMIENTO                  CAREPA                349
# 9   MATRICULA Y SOSTENIMIENTO               MARINILLA                290
# 10  MATRICULA Y SOSTENIMIENTO                  SONSON                262
# 11  MATRICULA Y SOSTENIMIENTO                   ANDES                254
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=conteo_de_becas,
            x='Total',
            y='beneficio_otorgado',
            palette='viridis')

plt.title('Número de Beneficiarios por Beneficio Otorgado')
plt.xlabel('Beneficio Otorgado')
plt.ylabel('Número de Beneficiarios')
plt.xticks(rotation=45)  # Para que las etiquetas de las barras no se sobrepongan
plt.tight_layout()

plt.show()

# %% [markdown]
# 3. ¿Cómo ha sido la evolución del acceso a estos beneficios en los últimos años?(conteo de convocatoria por año)

# %%
#conteo de # de beneficiarios por convocatoria
conteo_de_evolución = df.groupby('convocatoria')['convocatoria'].count().sort_values(ascending=False).reset_index(name='Total')
conteo_de_evolución
# Out:
#     convocatoria  Total
# 0           2014   3299
# 1           2015   3258
# 2           2013   2724
# 3           2019   1116
# 4           2016    946
# 5           2017    762
# 6           2020    744
# 7           2021    553
# 8           2022    441
# 9           2018    415
# 10          2023    265
# 11          2024     43

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=conteo_de_evolución,
    x='convocatoria',
    y='Total',
    palette='Blues_d'
)

# Agregar etiquetas con los valores encima de las barras
for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,  # posición X centrada
        height + 5,                         # posición Y justo arriba de la barra
        f'{int(height)}',                   # valor que se mostrará
        ha='center', va='bottom', fontsize=9
    )

plt.xlabel('Convocatoria')
plt.ylabel('Total de beneficiarios')
plt.title('Número de beneficiarios por convocatoria')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Pregunta 3

# GRAFICO 3 - EVOLUCIÓN DE BENEFICIARIOS POR AÑO

beneficiarios_por_anio = df['convocatoria'].value_counts().sort_index()

plt.figure(figsize=(10,5))
sns.lineplot(x=beneficiarios_por_anio.index, y=beneficiarios_por_anio.values, marker='o', color='teal')
plt.title("P3 - Evolución del acceso a beneficios educativos")
plt.xlabel("Año de Convocatoria")
plt.ylabel("N° de beneficiarios")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. ¿Cuál es el top 10 de las instituciones más frecuentes a las que acceden los beneficiarios? (universidad, conteo de año nac)

# %%
#contar las universidades más frecuentes
conteo_de_universidad = df.groupby('universidad')['convocatoria'].count().sort_values(ascending=False).reset_index(name='Total').head(10)
conteo_de_universidad
# Out:
#                                       universidad  Total
# 0                        UNIVERSIDAD DE ANTIOQUIA   4338
# 1      POLITECNICO COLOMBIANO JAIME ISAZA CADAVID   2448
# 2                        TECNOLOGICO DE ANTIOQUIA   1571
# 3                 UNIVERSIDAD CATOLICA DE ORIENTE    928
# 4         INSTITUCION UNIVERSITARIA PASCUAL BRAVO    796
# 5      FUNDACION UNIVERSITARIA CATOLICA DEL NORTE    765
# 6  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA    727
# 7                                          COREDI    530
# 8                                            SENA    490
# 9                UNIVERSIDAD NACIONAL DE COLOMBIA    454

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 12))
ax = sns.barplot(
    data=conteo_de_universidad,
    y='universidad',
    x='Total',
    palette='crest'
)

# Agregar valores al final de las barras
for bar in ax.patches:
    width = bar.get_width()
    ax.text(width + 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', va='center')

plt.xlabel('Total de beneficiarios')
plt.ylabel('Universidad')
plt.title('Top 20 instituciones más frecuentes entre los beneficiarios')
plt.tight_layout()
plt.show()

# %% [markdown]
# 5. ¿Qué nivel educativo es más demandado?

# %%
#Crear un nuevo df llamado df_lower donde toda la data estara en minuscula
df_lower = df.apply(lambda col: col.str.lower() if col.dtype == "object" else col)

# %%
df_lower
# Out:
#        convocatoria  semestre_de_convocatoria         beneficio_otorgado  \
# 0              2016                         1  matricula y sostenimiento
# 1              2016                         1  matricula y sostenimiento
# 2              2016                         1  matricula y sostenimiento
# 3              2016                         1  matricula y sostenimiento
# 4              2016                         1  matricula y sostenimiento
# ...             ...                       ...                        ...
# 14561          2024                         1              sostenimiento
# 14562          2024                         1              sostenimiento
# 14563          2024                         1              sostenimiento
# 14564          2024                         1              sostenimiento
# 14565          2024                         1              sostenimiento
#
#       departamento_de_nacimiento municipio_de_nacimiento     género  \
# ...

# %%
#agrupar tipo de formacion por convocatoria
conteo_de_nivel = df.groupby('tipo_de_formación')['convocatoria'].count().sort_values(ascending=False).reset_index(name='Total').head(10)
conteo_de_nivel
# Out:
#      tipo_de_formación  Total
# 0        universitaria   8368
# 1          tecnologica   5235
# 2  tecnica profesional    489
# 3           normalista    454
# 4            postgrado     20

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ordenar los valores para una presentación lógica
conteo_de_nivel = conteo_de_nivel.sort_values('Total', ascending=False)

plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=conteo_de_nivel,
    x='tipo_de_formación',
    y='Total',
    palette='viridis'
)

# Agregar valores encima de las barras
for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width()/2,
        height + 3,  # puedes ajustar este valor
        f'{int(height):,}',
        ha='center', va='bottom', fontsize=9
    )

# Personalizar ejes y título
plt.xlabel('Tipo de formación')
plt.ylabel('Total de beneficiarios')
plt.title('Cantidad de beneficiarios por tipo de formación')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   convocatoria                  14566 non-null  int64
#  1   semestre_de_convocatoria      14566 non-null  int64
#  2   beneficio_otorgado            14566 non-null  object
#  3   departamento_de_nacimiento    14566 non-null  object
#  4   municipio_de_nacimiento       14566 non-null  object
#  5   género                        14566 non-null  object
#  6   subregión_de_residencia       14566 non-null  object
#  7   municipio_de_residencia       14566 non-null  object
#  8   estrato                       14566 non-null  object
#  9   grupo_etnico                  14566 non-null  object
#  10  victima_del_conflicto_armado  14566 non-null  object
#  11  universidad                   14566 non-null  object
# ...

# %% [markdown]
# 6. ¿Qué porcentaje de beneficiarios corresponde a becas, créditos condonables o mixtos? (beneficio otorgado)

# %%
df['beneficio_otorgado'].value_counts()
# Out:
# beneficio_otorgado
# MATRICULA Y SOSTENIMIENTO    11431
# MATRICULA                     1579
# SOSTENIMIENTO                 1556
# Name: count, dtype: int64

# %%
personas=[11431,1579,1556]
beneficio=["Matricula y sostenimiento","Matricula","Sostenimieno"]

plt.pie(personas,labels=beneficio, autopct="%1.2f %%", colors=['red','blue','green','orange'], shadow=True, explode=(0.2,0.1,0))

plt.title("Porcentaje de beneficiarios por beneficio otorgado")
plt.show()

# %% [markdown]
# 7. ¿Qué municipios presentan mayor y menor cantidad de beneficiarios? (conteo de municipio de residencia)

# %%
# Contar beneficiarios por municipio
conteo_municipios = df['municipio_de_residencia'].value_counts()

# Obtener el municipio con mayor cantidad de beneficiarios
municipio_max = conteo_municipios.idxmax()
cantidad_max = conteo_municipios.max()

# Obtener el municipio con menor cantidad de beneficiarios
municipio_min = conteo_municipios.idxmin()
cantidad_min = conteo_municipios.min()

print(f"Municipio con mayor cantidad de beneficiarios: {municipio_max} ({cantidad_max})")
print(f"Municipio con menor cantidad de beneficiarios: {municipio_min} ({cantidad_min})")
# Out:
# Municipio con mayor cantidad de beneficiarios: RIONEGRO (1151)
# Municipio con menor cantidad de beneficiarios: ARMENIA (4)

# %%
# Datos
municipios = [municipio_max, municipio_min]
cantidades = [cantidad_max, cantidad_min]

# Tamaño del gráfico
plt.figure(figsize=(6, 4))

# Graficar puntos
plt.scatter(municipios, cantidades, color='red', s=100)

# Añadir texto a los puntos
for i in range(len(municipios)):
    plt.text(municipios[i], cantidades[i] + 1, str(cantidades[i]), ha='center')

plt.title('Municipios con más y menos beneficiarios')
plt.ylabel('Cantidad de beneficiarios')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# 8. ¿Qué subregiones de Antioquia están más rezagadas en términos de acceso a apoyos educativos? (subregion con menos apoyo)

# %%
# Contar beneficiarios por subregión
conteo_subregión_de_residencia = df['subregión_de_residencia'].value_counts()

# Obtener la subregión con menor cantidad de beneficiarios
subregión_de_residencia_min = conteo_subregión_de_residencia.idxmin()
cantidad_min = conteo_subregión_de_residencia.min()
print(f"Subregión con menor cantidad de beneficiarios: {subregión_de_residencia_min} ({cantidad_min})")
# Out:
# Subregión con menor cantidad de beneficiarios: MAGDALENA MEDIO (340)

# %%
#Datos
sizes = conteo_subregión_de_residencia.values
labels = conteo_subregión_de_residencia.index

#Crear explode, subregion que se destaca
explode = [0.1 if label == subregión_de_residencia_min else 0 for label in labels]

#Colores
colors = ['pink' if label == subregión_de_residencia_min else 'gray' for label in labels]

plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=explode, shadow=True)
plt.title('Distribución de beneficiarios por subregión (destacando la mínima)')
plt.show()

# %% [markdown]
# 9. ¿Cuáles son los programas académicos más demandados por genero, edad y subregion? (genero, programa cursado, subregion)

# %%
# Paso 1: Agrupar por 'género', 'edad', 'subregión_de_residencia' y 'programa_cursado' para contar la demanda de cada programa
df_count = df.groupby(['género', 'edad', 'subregión_de_residencia', 'programa_cursado']).size().reset_index(name='demanda')

# Paso 2: Para cada combinación de 'género', 'edad' y 'subregión_de_residencia', seleccionamos los 5 programas más demandados
top_5_programas = df_count.groupby(['género', 'edad', 'subregión_de_residencia']).apply(lambda x: x.nlargest(5, 'demanda')).reset_index(drop=True)

# Paso 3: Si necesitas solo los primeros 5 registros globales, seleccionamos los 5 primeros (total global, no por grupo)
top_5_programas_unicos = top_5_programas.head(5)

# Paso 4: Mostrar los resultados
print(top_5_programas_unicos)
# Out:
#      género  edad subregión_de_residencia  \
# 0  FEMENINO    13                NORDESTE
# 1  FEMENINO    14                NORDESTE
# 2  FEMENINO    14                   NORTE
# 3  FEMENINO    14               OCCIDENTE
# 4  FEMENINO    14               OCCIDENTE
#
#                                     programa_cursado  demanda
# 0                    TECNOLOGIA EN GESTION AMBIENTAL        1
# 1  ADMINISTRACION EN SEGURIDAD Y SALUD EN EL TRABAJO        1
# 2    TECNICA PROFESIONAL EN ATENCION PREHOSPITALARIA        1
# 3                                            DERECHO        1
# 4  TECNOLOGIA EN GESTION DE AGROINDUSTRIAS ALIMEN...        1
# ...

# %%
# Crear el gráfico de barras agrupadas (doble barra), usando tanto 'género' como 'subregión_de_residencia' como hue
plt.figure(figsize=(16, 8))

# Crear el gráfico de barras
sns.barplot(
    data=top_5_programas_unicos,
    x='programa_cursado',
    y='edad',
    hue='género',  # Primer 'hue' para los géneros
    errorbar=None,
    palette='Set2',
    dodge=True  # Asegura que las barras se muestren separadas
)

# Crear una segunda capa de barras para 'subregión_de_residencia'
sns.barplot(
    data=top_5_programas_unicos,
    x='programa_cursado',
    y='edad',
    hue='subregión_de_residencia',  # Segundo 'hue' para la subregión
    errorbar=None,
    palette='Pastel1',
    dodge=True  # Asegura que las barras se muestren separadas
)

# Añadir título y etiquetas
plt.title('Top 5 Programas Más Demandados por Género y Subregión de Residencia', fontsize=16)
plt.xlabel('Programa Cursado', fontsize=12)
plt.ylabel('Edad', fontsize=12)

# Ajustar la rotación de las etiquetas del eje X para mayor legibilidad
plt.xticks(rotation=45, ha="right")

# Mostrar leyenda y gráfico
plt.legend(title="Categorías", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **11. ¿Cuál es la distribución por género, estrato,grupo-etnico y victima del conflicto armado entre los beneficiarios alrededor de los años? (conteo de genero,año, estrato, conflicto armado)**

# %%
# Convertir todos los valores de la columna 'tipo_de_formacion' a mayúsculas
df['estrato'] = df['estrato'].str.upper()

# %%
distribucion = df.groupby(['género', 'estrato', 'grupo_etnico', 'victima_del_conflicto_armado']).size().reset_index(name='conteo')

# Mostrar el resultado
print(distribucion)
# Out:
#        género    estrato    grupo_etnico victima_del_conflicto_armado  conteo
# 0    FEMENINO  ESTRATO 1  AFROCOLOMBIANO                           NO     111
# 1    FEMENINO  ESTRATO 1  AFROCOLOMBIANO                           SI      79
# 2    FEMENINO  ESTRATO 1        INDIGENA                           NO      24
# 3    FEMENINO  ESTRATO 1        INDIGENA                           SI      29
# 4    FEMENINO  ESTRATO 1         NINGUNO                           NO    1485
# 5    FEMENINO  ESTRATO 1         NINGUNO                           SI    1036
# 6    FEMENINO  ESTRATO 2  AFROCOLOMBIANO                           NO      61
# 7    FEMENINO  ESTRATO 2  AFROCOLOMBIANO                           SI      36
# 8    FEMENINO  ESTRATO 2        INDIGENA                           NO       3
# 9    FEMENINO  ESTRATO 2        INDIGENA                           SI       4
# 10   FEMENINO  ESTRATO 2         NINGUNO                           NO    2701
# ...

# %%
# Filtramos los diferentes grupos étnicos
grupos_etnicos = distribucion['grupo_etnico'].unique()

# Crear un gráfico por cada grupo étnico
for grupo in grupos_etnicos:
    # Filtrar datos por el grupo étnico actual
    datos_grupo = distribucion[distribucion['grupo_etnico'] == grupo]

    # Crear una figura para cada gráfico
    plt.figure(figsize=(12, 8))

    # Gráfico de barras agrupadas para las tres variables (género, estrato, victima_conflicto_armado)
    sns.barplot(x='estrato', y='conteo', hue='género', data=datos_grupo, palette='Set2')

    # Título del gráfico
    plt.title(f'Distribución por Género, Estrato y Víctima del Conflicto Armado\nGrupo Étnico: {grupo}', fontsize=16)
    plt.xlabel('Estrato', fontsize=12)
    plt.ylabel('Número de Beneficiarios', fontsize=12)

    # Mostrar leyenda
    plt.legend(title='Género')

    # Ajustar la visualización
    plt.tight_layout()

    # Mostrar el gráfico
    plt.show()

    # Gráfico de barras agrupadas para víctimas del conflicto armado
    plt.figure(figsize=(12, 8))
    sns.barplot(x='estrato', y='conteo', hue='victima_del_conflicto_armado', data=datos_grupo, palette='coolwarm')

    # Título del gráfico
    plt.title(f'Distribución de Víctimas del Conflicto Armado por Estrato\nGrupo Étnico: {grupo}', fontsize=16)
    plt.xlabel('Estrato', fontsize=12)
    plt.ylabel('Número de Beneficiarios', fontsize=12)

    # Mostrar leyenda
    plt.legend(title='Víctima del Conflicto Armado')

    # Ajustar la visualización
    plt.tight_layout()

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# **12. ¿Qué grupo etario predomina entre los beneficiarios x genero?**

# %%
# Agrupar por 'género' y calcular el rango de edades por grupo
rango_edades_por_genero = df.groupby('género')['edad'].agg(['min', 'max'])

# Calcular el rango (diferencia entre max y min) para cada grupo
rango_edades_por_genero['rango'] = rango_edades_por_genero['max'] - rango_edades_por_genero['min']

# Mostrar el resultado
print(rango_edades_por_genero)
# Out:
#            min  max  rango
# género
# FEMENINO    13   57     44
# MASCULINO   14   62     48

# %%
# Crear un gráfico de líneas para el rango de edades por género
plt.figure(figsize=(8, 6))

# Graficar el rango de edades con un gráfico de líneas
sns.lineplot(data=rango_edades_por_genero, x=rango_edades_por_genero.index, y='rango', marker='o', color='purple')

# Añadir título y etiquetas
plt.title('Rango de Edad por Género', fontsize=16)
plt.xlabel('Género', fontsize=12)
plt.ylabel('Rango de Edad', fontsize=12)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
